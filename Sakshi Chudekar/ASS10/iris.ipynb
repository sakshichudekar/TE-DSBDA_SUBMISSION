# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')

# %%
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(iris.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.hist(figsize=(10, 8), edgecolor='black')
plt.suptitle("Feature Distributions - Histogram", fontsize=16)
plt.show()

# %%
sns.boxplot(y=iris['petal_width'], color='lightgreen')
plt.show()

# %%
sns.boxplot(y=iris['sepal_length'], color='lightgreen')
plt.show()

# %%
sns.boxplot(y=iris['petal_length'], color='lightgreen')
plt.show()
